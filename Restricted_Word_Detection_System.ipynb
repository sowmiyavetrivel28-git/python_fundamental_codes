# %% [markdown]
# <a href="https://colab.research.google.com/github/sowmiyavetrivel28-git/python_fundamental_codes/blob/main/Restricted_Word_Detection_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Case Study – Restricted Word Detection System**
#
# **Instructions:**
#
# 1. Create a list of words containing normal and restricted words.
#
# 2. Use a for loop to read words one by one.
#
# 3. Check whether the current word is a restricted word using if condition.
#
# 4. If the restricted word is found:
#    • Display "Restricted word detected"
#    • Stop the loop using break
#
# 5. Otherwise display all safe words using print()

# %%
#count the restricted words in list
# List of words
words = ["Hello", "Python", "Admin", "Blocked", "Welcome","Blocked","Hacker","Wrong"]

restricted_word=["Blocked","Hacker",'Wrong']

count=0

for word in words:

  if word in restricted_word:

    print(f"restricted_word : {word}")

    count+=1

print(f'total word in the list: {count}')
# Out:
# restricted_word : Blocked
# restricted_word : Blocked
# restricted_word : Hacker
# restricted_word : Wrong
# total word in the list: 4
