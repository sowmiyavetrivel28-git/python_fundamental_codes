# %% [markdown]
# <a href="https://colab.research.google.com/github/sowmiyavetrivel28-git/python_fundamental_codes/blob/main/employee_salary_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Instructions**
#
# Create a list called salary
#
# Store employee salaries inside the list
#
# Use list comprehension to:
# Increase each salary by 10%
#
# Create another list to:
# Display only salaries greater than 50000
#
# Print:
#
# Original salary list
#
# Updated salary list
#
# Filtered salary list

# %%
salary = [25000, 40000, 55000, 60000, 75000]

# Increment salary by 10%
updated_salary = [i * 1.10 for i in salary]

# Filter salaries greater than 50000
high_salary = [i for i in updated_salary if i > 50000]

print("Original Salary :", salary)
print("Updated Salary  :", updated_salary)
print("High Salary     :", high_salary)
# Out:
# Original Salary : [25000, 40000, 55000, 60000, 75000]
# Updated Salary  : [27500.000000000004, 44000.0, 60500.00000000001, 66000.0, 82500.0]
# High Salary     : [60500.00000000001, 66000.0, 82500.0]
