# %% [markdown]
# <a href="https://colab.research.google.com/github/sowmiyavetrivel28-git/python_fundamental_codes/blob/main/Sales_Tracking_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Case Study: Sales Tracking System**
#
# A retail store records sales transactions every day. The manager wants a Python function that can:
#
# Accept any number of sales amounts.
#
# Calculate the current day's total sales.
#
# Maintain a running total of all sales made till date.
#
# Display both the current sale total and the cumulative sales total.
#
# Task:
#
# Write a Python function total_sale(*sales) that uses a global variable to keep track of the total sales till date.

# %%
total_sales=0

def total_sale(*sales):
  global total_sales

  currentday_sales=sum(sales)
  total_sales+=currentday_sales

  print("Current day sales:", currentday_sales)
  print("Cumulative sales:", total_sales)


total_sale(100,300,250)

total_sale(200,300)
total_sale(1000,5000)

print("\ntotal sales:", total_sales)
# Out:
# Current day sales: 650
# Cumulative sales: 650
# Current day sales: 500
# Cumulative sales: 1150
# Current day sales: 6000
# Cumulative sales: 7150
#
# total sales: 7150
