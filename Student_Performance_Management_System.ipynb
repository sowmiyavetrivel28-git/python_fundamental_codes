# %% [markdown]
# <a href="https://colab.research.google.com/github/sowmiyavetrivel28-git/python_fundamental_codes/blob/main/Student_Performance_Management_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Case Study – Student Performance Management System
# Instructions
#
# Create two lists: students marks
#
# Use range() to: Access and print student names and marks using index positions
#
# Use enumerate() to: Display student index number and student name
#
# Use zip() to: Combine student names and marks together
#
# Display all outputs using for loops
#
# Use proper headings with print() statements
#
# Print the final result in a clean format

# %%
students=["sowmi","vetri","vidhun"]
marks=[56,98,87]

for i,(student,mark )in enumerate(zip(students,marks)):
  print(f"student {student} mark is {mark} in index {i}")
# Out:
# student sowmi mark is 56 in index 0
# student vetri mark is 98 in index 1
# student vidhun mark is 87 in index 2
