# %% [markdown]
# <a href="https://colab.research.google.com/github/sowmiyavetrivel28-git/python_fundamental_codes/blob/main/Student_Course_Registration_System_using_Set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Case Study – Student Course Registration System using Set
# Instructions:
#
# Create a set named courses with course names: Python, SQL, Power BI, Python, Excel
#
# Perform set operations: • Add course using add()
# • Add multiple courses using update()
# • Remove course using remove() and discard()
#
# Display all courses and total number of courses using len()

# %%
courses={"python","sql","powerBI","python","Excel"}

# ADD COURSES
courses.add("java")
print(f"affter add:{courses}")

#add multiple courses
courses.update(["javascript",'react'])
print(f"after update:{courses}")

# remove
courses.remove("java")
print(f"after remove:{courses}")

# discard

courses.discard("sql")
print(f'after discard:{courses}')

# display all courses
print(f"All courses:{courses}")

#len()
len(courses)
# Out:
# affter add:{'python', 'java', 'Excel', 'sql', 'powerBI'}
# after update:{'python', 'java', 'Excel', 'javascript', 'sql', 'react', 'powerBI'}
# after remove:{'python', 'Excel', 'javascript', 'sql', 'react', 'powerBI'}
# after discard:{'python', 'Excel', 'javascript', 'react', 'powerBI'}
# All courses:{'python', 'Excel', 'javascript', 'react', 'powerBI'}
# 5
