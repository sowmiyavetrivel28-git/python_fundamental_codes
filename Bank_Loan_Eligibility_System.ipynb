# %% [markdown]
# <a href="https://colab.research.google.com/github/sowmiyavetrivel28-git/python_fundamental_codes/blob/main/Bank_Loan_Eligibility_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##  **5. Case Study: Bank Loan Eligibility System**
# **Instructions:**
#
# 1. Create variables:
#    customer_name, age, income, credit_score, existing_loan
#
# 2. Use conditional statements (if, elif, else) to:
#
#    • Approve loan if age ≥ 21, income ≥ 30000,
#
#    -- credit_score ≥ 700, and no existing loan
#
#    • Conditionally approve loan if credit_score ≥ 600 and income ≥ 40000
#
#    • Otherwise reject the loan application
#
# 3. Display customer details and loan status using print()

# %%
customer_name = "bhat"
age = 32
income = 55000
credit_score = 720
existing_loan = True

if age>=21 and income>=30000:
  if credit_score>=700 and not existing_loan:
    status=" loan approved"
  elif credit_score>=600 and income>=40000:
    status='conditionally loan approved'

  else:
     status="rejected"
else:
   status="you are not eligible for loan"

print(f"customer name:{customer_name}")
print(f"age:{age}")
print(f"income:{income}")
print(f'credit_score:{credit_score}')
print(f"existing_loan:{existing_loan}")
print(f"status:{status}")
# Out:
# customer name:bhat
# age:32
# income:55000
# credit_score:720
# existing_loan:True
# status:conditionally loan approved
